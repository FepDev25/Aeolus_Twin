# %%
import pandas as pd
import os
from pathlib import Path
import glob

# %%
# Rutas
ROOT_PATHS = [
    Path("0 REPORTES DIARIOS 2024"),
    Path("1 REPORTES DIARIOS 2025")
]
OUTPUT_PATH = Path("procesados")
OUTPUT_PATH.mkdir(parents=True, exist_ok=True)

# %%
# Mapeo de nombres de los archivos
FILES_CONFIG = {
    "Generator speed": "GEN",
    "wind speed and wind direction": "WIND",
    "ActivePower": "PWR",
    "Air density": "AIR"
}

# %%
# Se procesan los 4 csvs por dia y los une
def procesar_dia(day_folder):
    dfs = []
    archivos_faltantes = []

    for keyword, prefix in FILES_CONFIG.items():
        try:
            #case-insensitive para manejar cambios en nombres
            file_path = None
            for archivo in day_folder.glob("*.csv"):
                if keyword.lower() in archivo.name.lower():
                    file_path = archivo
                    break
            
            if file_path is None:
                raise StopIteration
            
            df = pd.read_csv(file_path)
            df.columns = [c.strip() for c in df.columns]

            if 'Time' not in df.columns:
                print(f"'Time' no aparece en {file_path.name}")
                continue
            
            df["Time"] = pd.to_datetime(df["Time"], errors='coerce')
            df = df.dropna(subset=['Time'])
            
            if df.empty:
                print(f"{file_path.name} no tiene datos válidos")
                continue

            cols_data = [c for c in df.columns if c not in ["Time", "Number", "Wind turbine"]]
            rename_map = {c: f"{prefix}_{c}" for c in cols_data}
            df = df.rename(columns=rename_map)
            df = df[["Time"] + list(rename_map.values())]
            df = df.groupby("Time").mean().reset_index()
            df = df.set_index("Time")
            dfs.append(df)
        except StopIteration:
            archivos_faltantes.append(keyword)
        except Exception as e:
            print(f"Error leyendo {keyword} en {day_folder.name}: {e}")
    
    if archivos_faltantes:
        print(f"Faltan: {', '.join(archivos_faltantes)}")
    
    if dfs:
        full_df = pd.concat(dfs, axis=1, join='outer')
        return full_df.reset_index()
    return None

# %%
def main():
    total_dias = 0

    # procesar los dos años
    for ROOT_PATH in ROOT_PATHS:
        if not ROOT_PATH.exists():
            print(f"No existe: {ROOT_PATH}")
            continue
        
        print(f"\nProcesando año: {ROOT_PATH}")
        
        # carpetas de meses
        for month_folder in sorted(ROOT_PATH.glob("*_*")):
            if not month_folder.is_dir():
                continue
            
            print(f"\nMes: {month_folder.name}")
            
            # carpetas de dias
            for day_folder in sorted(month_folder.glob("202*")):
                if not day_folder.is_dir():
                    continue
                
                # Verificar si ya existe el archivo procesado
                output_file = OUTPUT_PATH / f"data_{day_folder.name}.parquet"
                if output_file.exists():
                    continue

                print(f"Procesando: {day_folder.name}")
                df_dia = procesar_dia(day_folder)

                if df_dia is not None and not df_dia.empty:
                    df_dia.to_parquet(output_file, index=False)
                    total_dias += 1
                    print(f"Guardado: {output_file.name}")
                else:
                    print(f"No se generó data para {day_folder.name}")

    print(f"Total de dias procesados: {total_dias}")

if __name__ == "__main__":
    main()
# Out:
# Procesando año: 0 REPORTES DIARIOS 2024
#
# Mes: 01_Enero
# Procesando: 20240101
# Guardado: data_20240101.parquet
# Procesando: 20240102
# Guardado: data_20240102.parquet
# Procesando: 20240103
# Guardado: data_20240103.parquet
# Procesando: 20240104
# Guardado: data_20240104.parquet
# Procesando: 20240105
# Guardado: data_20240105.parquet
# Procesando: 20240106
# Guardado: data_20240106.parquet
# Procesando: 20240107
# Guardado: data_20240107.parquet
# Procesando: 20240108
# Guardado: data_20240108.parquet
# Procesando: 20240109
# Guardado: data_20240109.parquet
# Procesando: 20240110
# Guardado: data_20240110.parquet
# Procesando: 20240111
# Guardado: data_20240111.parquet
# Procesando: 20240112
# Guardado: data_20240112.parquet
# Procesando: 20240113
# Guardado: data_20240113.parquet
# Procesando: 20240114
# Guardado: data_20240114.parquet
# Procesando: 20240115
# Guardado: data_20240115.parquet
# Procesando: 20240116
# Guardado: data_20240116.parquet
# Procesando: 20240117
# Guardado: data_20240117.parquet
# Procesando: 20240118
# Guardado: data_20240118.parquet
# Procesando: 20240119
# Guardado: data_20240119.parquet
# Procesando: 20240120
# Guardado: data_20240120.parquet
# Procesando: 20240121
# Guardado: data_20240121.parquet
# Procesando: 20240122
# Guardado: data_20240122.parquet
# Procesando: 20240123
# Guardado: data_20240123.parquet
# Procesando: 20240124
# Guardado: data_20240124.parquet
# Procesando: 20240125
# Guardado: data_20240125.parquet
# Procesando: 20240126
# Guardado: data_20240126.parquet
# Procesando: 20240127
# Guardado: data_20240127.parquet
# Procesando: 20240128
# Guardado: data_20240128.parquet
# Procesando: 20240129
# Guardado: data_20240129.parquet
# Procesando: 20240130
# Guardado: data_20240130.parquet
# Procesando: 20240131
# Guardado: data_20240131.parquet
#
# Mes: 02_Febrero
# Procesando: 20240201
# Guardado: data_20240201.parquet
# Procesando: 20240202
# Guardado: data_20240202.parquet
# Procesando: 20240203
# Guardado: data_20240203.parquet
# Procesando: 20240204
# Guardado: data_20240204.parquet
# Procesando: 20240205
# Guardado: data_20240205.parquet
# Procesando: 20240206
# Guardado: data_20240206.parquet
# Procesando: 20240207
# Guardado: data_20240207.parquet
# Procesando: 20240208
# Guardado: data_20240208.parquet
# Procesando: 20240209
# Guardado: data_20240209.parquet
# Procesando: 20240210
# Guardado: data_20240210.parquet
# Procesando: 20240211
# Guardado: data_20240211.parquet
# Procesando: 20240212
# Guardado: data_20240212.parquet
# Procesando: 20240213
# Guardado: data_20240213.parquet
# Procesando: 20240214
# Guardado: data_20240214.parquet
# Procesando: 20240215
# Guardado: data_20240215.parquet
# Procesando: 20240216
# Guardado: data_20240216.parquet
# Procesando: 20240217
# Guardado: data_20240217.parquet
# Procesando: 20240218
# Guardado: data_20240218.parquet
# Procesando: 20240219
# Guardado: data_20240219.parquet
# Procesando: 20240220
# Guardado: data_20240220.parquet
# Procesando: 20240221
# Guardado: data_20240221.parquet
# Procesando: 20240222
# Guardado: data_20240222.parquet
# Procesando: 20240223
# Guardado: data_20240223.parquet
# Procesando: 20240224
# Guardado: data_20240224.parquet
# Procesando: 20240225
# Guardado: data_20240225.parquet
# Procesando: 20240226
# Guardado: data_20240226.parquet
# Procesando: 20240227
# Guardado: data_20240227.parquet
# Procesando: 20240228
# Guardado: data_20240228.parquet
# Procesando: 20240229
# Guardado: data_20240229.parquet
#
# Mes: 03_Marzo
# Procesando: 20240301
# Guardado: data_20240301.parquet
# Procesando: 20240302
# Guardado: data_20240302.parquet
# Procesando: 202403027
# Guardado: data_202403027.parquet
# Procesando: 202403028
# Guardado: data_202403028.parquet
# Procesando: 202403029
# Guardado: data_202403029.parquet
# Procesando: 20240303
# Guardado: data_20240303.parquet
# Procesando: 202403030
# Guardado: data_202403030.parquet
# Procesando: 202403031
# Guardado: data_202403031.parquet
# Procesando: 20240304
# Guardado: data_20240304.parquet
# Procesando: 20240305
# Guardado: data_20240305.parquet
# Procesando: 20240306
# Guardado: data_20240306.parquet
# Procesando: 20240307
# Guardado: data_20240307.parquet
# Procesando: 20240308
# Guardado: data_20240308.parquet
# Procesando: 20240309
# Guardado: data_20240309.parquet
# Procesando: 20240310
# Guardado: data_20240310.parquet
# Procesando: 20240311
# Guardado: data_20240311.parquet
# Procesando: 20240312
# Guardado: data_20240312.parquet
# Procesando: 20240313
# Guardado: data_20240313.parquet
# Procesando: 20240314
# Guardado: data_20240314.parquet
# Procesando: 20240315
# Guardado: data_20240315.parquet
# Procesando: 20240316
# Guardado: data_20240316.parquet
# Procesando: 20240317
# Guardado: data_20240317.parquet
# Procesando: 20240318
# Guardado: data_20240318.parquet
# Procesando: 20240319
# Guardado: data_20240319.parquet
# Procesando: 20240320
# Guardado: data_20240320.parquet
# Procesando: 20240321
# Guardado: data_20240321.parquet
# Procesando: 20240322
# Guardado: data_20240322.parquet
# Procesando: 20240323
# Guardado: data_20240323.parquet
# Procesando: 20240324
# Guardado: data_20240324.parquet
# Procesando: 20240325
# Guardado: data_20240325.parquet
# Procesando: 20240326
# Guardado: data_20240326.parquet
#
# Mes: 04_Abril
# Procesando: 20240401
# Guardado: data_20240401.parquet
# Procesando: 20240402
# Guardado: data_20240402.parquet
# Procesando: 20240403
# Guardado: data_20240403.parquet
# Procesando: 20240404
# Guardado: data_20240404.parquet
# Procesando: 20240405
# Guardado: data_20240405.parquet
# Procesando: 20240406
# Guardado: data_20240406.parquet
# Procesando: 20240407
# Guardado: data_20240407.parquet
# Procesando: 20240408
# Guardado: data_20240408.parquet
# Procesando: 20240409
# Guardado: data_20240409.parquet
# Procesando: 20240410
# Guardado: data_20240410.parquet
# Procesando: 20240411
# Guardado: data_20240411.parquet
# Procesando: 20240412
# Guardado: data_20240412.parquet
# Procesando: 20240413
# Guardado: data_20240413.parquet
# Procesando: 20240414
# Guardado: data_20240414.parquet
# Procesando: 20240415
# Guardado: data_20240415.parquet
# Procesando: 20240416
# Guardado: data_20240416.parquet
# Procesando: 20240417
# Guardado: data_20240417.parquet
# Procesando: 20240418
# Guardado: data_20240418.parquet
# Procesando: 20240419
# Guardado: data_20240419.parquet
# Procesando: 20240420
# Guardado: data_20240420.parquet
# Procesando: 20240421
# Guardado: data_20240421.parquet
# Procesando: 20240422
# Guardado: data_20240422.parquet
# Procesando: 20240423
# Guardado: data_20240423.parquet
# Procesando: 20240424
# Guardado: data_20240424.parquet
# Procesando: 20240425
# Guardado: data_20240425.parquet
# Procesando: 20240426
# Guardado: data_20240426.parquet
# Procesando: 20240427
# Guardado: data_20240427.parquet
# Procesando: 20240428
# Guardado: data_20240428.parquet
# Procesando: 20240429
# Guardado: data_20240429.parquet
# Procesando: 20240430
# Guardado: data_20240430.parquet
#
# Mes: 05_Mayo
# Procesando: 20240501
# Guardado: data_20240501.parquet
# Procesando: 20240502
# Guardado: data_20240502.parquet
# Procesando: 20240503
# Guardado: data_20240503.parquet
# Procesando: 20240504
# Guardado: data_20240504.parquet
# Procesando: 20240505
# Guardado: data_20240505.parquet
# Procesando: 20240506
# Guardado: data_20240506.parquet
# Procesando: 20240507
# Guardado: data_20240507.parquet
# Procesando: 20240508
# Guardado: data_20240508.parquet
# Procesando: 20240509
# Guardado: data_20240509.parquet
# Procesando: 20240510
# Guardado: data_20240510.parquet
# Procesando: 20240511
# Guardado: data_20240511.parquet
# Procesando: 20240512
# Guardado: data_20240512.parquet
# Procesando: 20240513
# Guardado: data_20240513.parquet
# Procesando: 20240514
# Guardado: data_20240514.parquet
# Procesando: 20240515
# Guardado: data_20240515.parquet
# Procesando: 20240516
# Guardado: data_20240516.parquet
# Procesando: 20240517
# Guardado: data_20240517.parquet
# Procesando: 20240518
# Guardado: data_20240518.parquet
# Procesando: 20240519
# Guardado: data_20240519.parquet
# Procesando: 20240520
# Guardado: data_20240520.parquet
# Procesando: 20240521
# Guardado: data_20240521.parquet
# Procesando: 20240522
# Guardado: data_20240522.parquet
# Procesando: 20240523
# Guardado: data_20240523.parquet
# Procesando: 20240524
# Guardado: data_20240524.parquet
# Procesando: 20240525
# Guardado: data_20240525.parquet
# Procesando: 20240526
# Guardado: data_20240526.parquet
# Procesando: 20240527
# Guardado: data_20240527.parquet
# Procesando: 20240528
# Guardado: data_20240528.parquet
# Procesando: 20240529
# Guardado: data_20240529.parquet
# Procesando: 20240530
# Guardado: data_20240530.parquet
# Procesando: 20240531
# Guardado: data_20240531.parquet
#
# Mes: 06_Junio
# Procesando: 20240601
# Guardado: data_20240601.parquet
# Procesando: 20240602
# Guardado: data_20240602.parquet
# Procesando: 20240603
# Guardado: data_20240603.parquet
# Procesando: 20240604
# Guardado: data_20240604.parquet
# Procesando: 20240605
# Guardado: data_20240605.parquet
# Procesando: 20240606
# Guardado: data_20240606.parquet
# Procesando: 20240607
# Guardado: data_20240607.parquet
# Procesando: 20240608
# Guardado: data_20240608.parquet
# Procesando: 20240609
# Guardado: data_20240609.parquet
# Procesando: 20240610
# Guardado: data_20240610.parquet
# Procesando: 20240611
# Guardado: data_20240611.parquet
# Procesando: 20240612
# Guardado: data_20240612.parquet
# Procesando: 20240613
# Guardado: data_20240613.parquet
# Procesando: 20240614
# Guardado: data_20240614.parquet
# Procesando: 20240615
# Guardado: data_20240615.parquet
# Procesando: 20240616
# Guardado: data_20240616.parquet
# Procesando: 20240617
# Guardado: data_20240617.parquet
# Procesando: 20240618
# Guardado: data_20240618.parquet
# Procesando: 20240619
# Guardado: data_20240619.parquet
# Procesando: 20240620
# Guardado: data_20240620.parquet
# Procesando: 20240621
# Guardado: data_20240621.parquet
# Procesando: 20240622
# Guardado: data_20240622.parquet
# Procesando: 20240623
# Guardado: data_20240623.parquet
# Procesando: 20240624
# Guardado: data_20240624.parquet
# Procesando: 20240625
# Guardado: data_20240625.parquet
# Procesando: 20240626
# Guardado: data_20240626.parquet
# Procesando: 20240627
# Guardado: data_20240627.parquet
# Procesando: 20240628
# Guardado: data_20240628.parquet
# Procesando: 20240629
# Guardado: data_20240629.parquet
# Procesando: 20240630
# Guardado: data_20240630.parquet
#
# Mes: 07_Julio
# Procesando: 20240701
# Guardado: data_20240701.parquet
# Procesando: 20240702
# Guardado: data_20240702.parquet
# Procesando: 20240703
# Guardado: data_20240703.parquet
# Procesando: 20240704
# Guardado: data_20240704.parquet
# Procesando: 20240705
# Guardado: data_20240705.parquet
# Procesando: 20240706
# Guardado: data_20240706.parquet
# Procesando: 20240707
# Guardado: data_20240707.parquet
# Procesando: 20240708
# Guardado: data_20240708.parquet
# Procesando: 20240709
# Guardado: data_20240709.parquet
# Procesando: 20240710
# Guardado: data_20240710.parquet
# Procesando: 20240711
# Guardado: data_20240711.parquet
# Procesando: 20240712
# Guardado: data_20240712.parquet
# Procesando: 20240713
# Guardado: data_20240713.parquet
# Procesando: 20240714
# Guardado: data_20240714.parquet
# Procesando: 20240715
# Guardado: data_20240715.parquet
# Procesando: 20240716
# Guardado: data_20240716.parquet
# Procesando: 20240717
# Guardado: data_20240717.parquet
# Procesando: 20240718
# Guardado: data_20240718.parquet
# Procesando: 20240719
# Guardado: data_20240719.parquet
# Procesando: 20240720
# Guardado: data_20240720.parquet
# Procesando: 20240721
# Guardado: data_20240721.parquet
# Procesando: 20240722
# Guardado: data_20240722.parquet
# Procesando: 20240723
# Guardado: data_20240723.parquet
# Procesando: 20240724
# Guardado: data_20240724.parquet
# Procesando: 20240725
# Guardado: data_20240725.parquet
# Procesando: 20240726
# Guardado: data_20240726.parquet
# Procesando: 20240727
# Guardado: data_20240727.parquet
# Procesando: 20240728
# Guardado: data_20240728.parquet
# Procesando: 20240729
# Guardado: data_20240729.parquet
# Procesando: 20240730
# Guardado: data_20240730.parquet
# Procesando: 20240731
# Guardado: data_20240731.parquet
#
# Mes: 08_Agosto
# Procesando: 20240801
# Guardado: data_20240801.parquet
# Procesando: 20240802
# Guardado: data_20240802.parquet
# Procesando: 20240803
# Guardado: data_20240803.parquet
# Procesando: 20240804
# Guardado: data_20240804.parquet
# Procesando: 20240805
# Guardado: data_20240805.parquet
# Procesando: 20240806
# Guardado: data_20240806.parquet
# Procesando: 20240807
# Guardado: data_20240807.parquet
# Procesando: 20240808
# Guardado: data_20240808.parquet
# Procesando: 20240809
# Guardado: data_20240809.parquet
# Procesando: 20240810
# Guardado: data_20240810.parquet
# Procesando: 20240811
# Guardado: data_20240811.parquet
# Procesando: 20240812
# Guardado: data_20240812.parquet
# Procesando: 20240813
# Guardado: data_20240813.parquet
# Procesando: 20240814
# Guardado: data_20240814.parquet
# Procesando: 20240815
# Guardado: data_20240815.parquet
# Procesando: 20240816
# Guardado: data_20240816.parquet
# Procesando: 20240817
# Guardado: data_20240817.parquet
# Procesando: 20240818
# Guardado: data_20240818.parquet
# Procesando: 20240819
# Guardado: data_20240819.parquet
# Procesando: 20240820
# Guardado: data_20240820.parquet
# Procesando: 20240821
# Guardado: data_20240821.parquet
# Procesando: 20240822
# Guardado: data_20240822.parquet
# Procesando: 20240823
# Guardado: data_20240823.parquet
# Procesando: 20240824
# Guardado: data_20240824.parquet
# Procesando: 20240825
# Guardado: data_20240825.parquet
# Procesando: 20240826
# Guardado: data_20240826.parquet
# Procesando: 20240827
# Guardado: data_20240827.parquet
# Procesando: 20240828
# Guardado: data_20240828.parquet
# Procesando: 20240829
# Guardado: data_20240829.parquet
# Procesando: 20240830
# Guardado: data_20240830.parquet
# Procesando: 20240831
# Guardado: data_20240831.parquet
#
# Mes: 09_Septiembre
# Procesando: 20240901
# Guardado: data_20240901.parquet
# Procesando: 20240902
# Guardado: data_20240902.parquet
# Procesando: 20240903
# Guardado: data_20240903.parquet
# Procesando: 20240904
# Guardado: data_20240904.parquet
# Procesando: 20240905
# Guardado: data_20240905.parquet
# Procesando: 20240906
# Guardado: data_20240906.parquet
# Procesando: 20240907
# Guardado: data_20240907.parquet
# Procesando: 20240908
# Guardado: data_20240908.parquet
# Procesando: 20240909
# Guardado: data_20240909.parquet
# Procesando: 20240910
# Guardado: data_20240910.parquet
# Procesando: 20240911
# Guardado: data_20240911.parquet
# Procesando: 20240912
# Guardado: data_20240912.parquet
# Procesando: 20240913
# Guardado: data_20240913.parquet
# Procesando: 20240914
# Guardado: data_20240914.parquet
# Procesando: 20240915
# Guardado: data_20240915.parquet
# Procesando: 20240916
# Guardado: data_20240916.parquet
# Procesando: 20240917
# Guardado: data_20240917.parquet
# Procesando: 20240918
# Guardado: data_20240918.parquet
# Procesando: 20240919
# Guardado: data_20240919.parquet
# Procesando: 20240920
# Guardado: data_20240920.parquet
# Procesando: 20240921
# Guardado: data_20240921.parquet
# Procesando: 20240922
# Guardado: data_20240922.parquet
# Procesando: 20240923
# Guardado: data_20240923.parquet
# Procesando: 20240924
# Guardado: data_20240924.parquet
# Procesando: 20240925
# Guardado: data_20240925.parquet
# Procesando: 20240926
# Guardado: data_20240926.parquet
# Procesando: 20240927
# Guardado: data_20240927.parquet
# Procesando: 20240928
# Guardado: data_20240928.parquet
# Procesando: 20240929
# Guardado: data_20240929.parquet
# Procesando: 20240930
# Guardado: data_20240930.parquet
#
# Mes: 10_Octubre
# Procesando: 20241001
# Guardado: data_20241001.parquet
# Procesando: 20241002
# Guardado: data_20241002.parquet
# Procesando: 20241003
# Guardado: data_20241003.parquet
# Procesando: 20241004
# Guardado: data_20241004.parquet
# Procesando: 20241005
# Guardado: data_20241005.parquet
# Procesando: 20241006
# Guardado: data_20241006.parquet
# Procesando: 20241007
# Guardado: data_20241007.parquet
# Procesando: 20241008
# Guardado: data_20241008.parquet
# Procesando: 20241009
# Guardado: data_20241009.parquet
# Procesando: 20241010
# Guardado: data_20241010.parquet
# Procesando: 20241011
# Guardado: data_20241011.parquet
# Procesando: 20241012
# Guardado: data_20241012.parquet
# Procesando: 20241013
# Guardado: data_20241013.parquet
# Procesando: 20241014
# Guardado: data_20241014.parquet
# Procesando: 20241015
# Guardado: data_20241015.parquet
# Procesando: 20241016
# Guardado: data_20241016.parquet
# Procesando: 20241017
# Guardado: data_20241017.parquet
# Procesando: 20241018
# Guardado: data_20241018.parquet
# Procesando: 20241019
# Guardado: data_20241019.parquet
# Procesando: 20241020
# Guardado: data_20241020.parquet
# Procesando: 20241021
# Guardado: data_20241021.parquet
# Procesando: 20241022
# Guardado: data_20241022.parquet
# Procesando: 20241023
# Guardado: data_20241023.parquet
# Procesando: 20241024
# Guardado: data_20241024.parquet
# Procesando: 20241025
# Guardado: data_20241025.parquet
# Procesando: 20241026
# Guardado: data_20241026.parquet
# Procesando: 20241027
# Guardado: data_20241027.parquet
# Procesando: 20241028
# Guardado: data_20241028.parquet
# Procesando: 20241029
# Guardado: data_20241029.parquet
# Procesando: 20241030
# Guardado: data_20241030.parquet
# Procesando: 20241031
# Guardado: data_20241031.parquet
#
# Mes: 11_Noviembre
# Procesando: 20241101
# Guardado: data_20241101.parquet
# Procesando: 20241102
# Guardado: data_20241102.parquet
# Procesando: 20241103
# Guardado: data_20241103.parquet
# Procesando: 20241104
# Guardado: data_20241104.parquet
# Procesando: 20241105
# Guardado: data_20241105.parquet
# Procesando: 20241106
# Guardado: data_20241106.parquet
# Procesando: 20241107
# Guardado: data_20241107.parquet
# Procesando: 20241108
# Guardado: data_20241108.parquet
# Procesando: 20241109
# Guardado: data_20241109.parquet
# Procesando: 20241110
# Guardado: data_20241110.parquet
# Procesando: 20241111
# Guardado: data_20241111.parquet
# Procesando: 20241112
# Guardado: data_20241112.parquet
# Procesando: 20241113
# Guardado: data_20241113.parquet
# Procesando: 20241114
# Guardado: data_20241114.parquet
# Procesando: 20241115
# Guardado: data_20241115.parquet
# Procesando: 20241116
# Guardado: data_20241116.parquet
# Procesando: 20241117
# Guardado: data_20241117.parquet
# Procesando: 20241118
# Guardado: data_20241118.parquet
# Procesando: 20241119
# Guardado: data_20241119.parquet
# Procesando: 20241120
# Guardado: data_20241120.parquet
# Procesando: 20241121
# Guardado: data_20241121.parquet
# Procesando: 20241122
# Guardado: data_20241122.parquet
# Procesando: 20241123
# Guardado: data_20241123.parquet
# Procesando: 20241124
# Guardado: data_20241124.parquet
# Procesando: 20241125
# Guardado: data_20241125.parquet
# Procesando: 20241126
# Guardado: data_20241126.parquet
# Procesando: 20241127
# Guardado: data_20241127.parquet
# Procesando: 20241128
# Guardado: data_20241128.parquet
# Procesando: 20241129
# Guardado: data_20241129.parquet
# Procesando: 20241130
# Guardado: data_20241130.parquet
#
# Mes: 12_Diciembre
# Procesando: 20241201
# Guardado: data_20241201.parquet
# Procesando: 20241202
# Guardado: data_20241202.parquet
# Procesando: 20241203
# Guardado: data_20241203.parquet
# Procesando: 20241204
# Guardado: data_20241204.parquet
# Procesando: 20241205
# Guardado: data_20241205.parquet
# Procesando: 20241206
# Guardado: data_20241206.parquet
# Procesando: 20241207
# Guardado: data_20241207.parquet
# Procesando: 20241207 - copia
# Guardado: data_20241207 - copia.parquet
# Procesando: 20241208
# Guardado: data_20241208.parquet
# Procesando: 20241208 - copia
# Guardado: data_20241208 - copia.parquet
# Procesando: 20241209
# 'Time' no aparece en Generator speed 2024-12-09.csv
# 'Time' no aparece en wind speed and wind direction_2024-12-09.csv
# 'Time' no aparece en ActivePower_2024-12-09.csv
# 'Time' no aparece en Air density_2024-12-09.csv
# No se generó data para 20241209
# Procesando: 20241209 - copia
# Guardado: data_20241209 - copia.parquet
# Procesando: 20241210
# 'Time' no aparece en Generator speed 2024-12-10.csv
# 'Time' no aparece en wind speed and wind direction_2024-12-10.csv
# 'Time' no aparece en ActivePower_2024-12-10.csv
# 'Time' no aparece en Air density_2024-12-10.csv
# No se generó data para 20241210
# Procesando: 20241210 - copia
# Guardado: data_20241210 - copia.parquet
# Procesando: 20241211
# Guardado: data_20241211.parquet
# Procesando: 20241212
# Guardado: data_20241212.parquet
# Procesando: 20241213
# Guardado: data_20241213.parquet
# Procesando: 20241214
# Guardado: data_20241214.parquet
# Procesando: 20241215
# Guardado: data_20241215.parquet
# Procesando: 20241216
# Guardado: data_20241216.parquet
# Procesando: 20241217
# Guardado: data_20241217.parquet
# Procesando: 20241218
# Guardado: data_20241218.parquet
# Procesando: 20241219
# Guardado: data_20241219.parquet
# Procesando: 20241220
# Guardado: data_20241220.parquet
# Procesando: 20241221
# Guardado: data_20241221.parquet
# Procesando: 20241222
# Guardado: data_20241222.parquet
# Procesando: 20241223
# Guardado: data_20241223.parquet
# Procesando: 20241224
# Guardado: data_20241224.parquet
# Procesando: 20241225
# Guardado: data_20241225.parquet
# Procesando: 20241226
# Guardado: data_20241226.parquet
# Procesando: 20241227
# Guardado: data_20241227.parquet
# Procesando: 20241228
# Guardado: data_20241228.parquet
# Procesando: 20241229
# Guardado: data_20241229.parquet
# Procesando: 20241230
# Guardado: data_20241230.parquet
# Procesando: 20241231
# Guardado: data_20241231.parquet
#
# Procesando año: 1 REPORTES DIARIOS 2025
#
# Mes: 01_Enero
# Procesando: 20250101
# Guardado: data_20250101.parquet
# Procesando: 20250102
# Guardado: data_20250102.parquet
# Procesando: 20250103
# Guardado: data_20250103.parquet
# Procesando: 20250104
# Guardado: data_20250104.parquet
# Procesando: 20250105
# Guardado: data_20250105.parquet
# Procesando: 20250106
# Guardado: data_20250106.parquet
# Procesando: 20250107
# Guardado: data_20250107.parquet
# Procesando: 20250108
# Guardado: data_20250108.parquet
# Procesando: 20250109
# Guardado: data_20250109.parquet
# Procesando: 20250110
# Guardado: data_20250110.parquet
# Procesando: 20250111
# Guardado: data_20250111.parquet
# Procesando: 20250112
# Guardado: data_20250112.parquet
# Procesando: 20250113
# Guardado: data_20250113.parquet
# Procesando: 20250114
# Guardado: data_20250114.parquet
# Procesando: 20250115
# Guardado: data_20250115.parquet
# Procesando: 20250116
# Guardado: data_20250116.parquet
# Procesando: 20250117
# Guardado: data_20250117.parquet
# Procesando: 20250118
# Guardado: data_20250118.parquet
# Procesando: 20250119
# Guardado: data_20250119.parquet
# Procesando: 20250120
# Guardado: data_20250120.parquet
# Procesando: 20250121
# Guardado: data_20250121.parquet
# Procesando: 20250122
# Guardado: data_20250122.parquet
# Procesando: 20250123
# Guardado: data_20250123.parquet
# Procesando: 20250124
# Guardado: data_20250124.parquet
# Procesando: 20250125
# Guardado: data_20250125.parquet
# Procesando: 20250126
# Guardado: data_20250126.parquet
# Procesando: 20250127
# Guardado: data_20250127.parquet
# Procesando: 20250128
# Guardado: data_20250128.parquet
# Procesando: 20250129
# Guardado: data_20250129.parquet
# Procesando: 20250130
# Guardado: data_20250130.parquet
# Procesando: 20250131
# Guardado: data_20250131.parquet
#
# Mes: 02_Febrero
# Procesando: 20250201
# Guardado: data_20250201.parquet
# Procesando: 20250202
# Guardado: data_20250202.parquet
# Procesando: 20250203
# Guardado: data_20250203.parquet
# Procesando: 20250204
# Guardado: data_20250204.parquet
# Procesando: 20250205
# Guardado: data_20250205.parquet
# Procesando: 20250206
# Guardado: data_20250206.parquet
# Procesando: 20250207
# Guardado: data_20250207.parquet
# Procesando: 20250208
# Guardado: data_20250208.parquet
# Procesando: 20250209
# Guardado: data_20250209.parquet
# Procesando: 20250210
# Guardado: data_20250210.parquet
# Procesando: 20250211
# Guardado: data_20250211.parquet
# Procesando: 20250212
# Guardado: data_20250212.parquet
# Procesando: 20250213
# Guardado: data_20250213.parquet
# Procesando: 20250214
# Guardado: data_20250214.parquet
# Procesando: 20250215
# Guardado: data_20250215.parquet
# Procesando: 20250216
# Guardado: data_20250216.parquet
# Procesando: 20250217
# Guardado: data_20250217.parquet
# Procesando: 20250218
# Guardado: data_20250218.parquet
# Procesando: 20250219
# Guardado: data_20250219.parquet
# Procesando: 20250220
# Guardado: data_20250220.parquet
# Procesando: 20250221
# Guardado: data_20250221.parquet
# Procesando: 20250222
# Guardado: data_20250222.parquet
# Procesando: 20250223
# Guardado: data_20250223.parquet
# Procesando: 20250224
# Guardado: data_20250224.parquet
# Procesando: 20250225
# Guardado: data_20250225.parquet
# Procesando: 20250226
# Guardado: data_20250226.parquet
# Procesando: 20250227
# Error leyendo ActivePower en 20250227: 'utf-8' codec can't decode byte 0xd0 in position 0: invalid continuation byte
# Guardado: data_20250227.parquet
# Procesando: 20250228
# Guardado: data_20250228.parquet
#
# Mes: 03_Marzo
# Procesando: 20250301
# Guardado: data_20250301.parquet
# Procesando: 20250302
# Guardado: data_20250302.parquet
# Procesando: 20250303
# Guardado: data_20250303.parquet
# Procesando: 20250304
# Guardado: data_20250304.parquet
# Procesando: 20250305
# Guardado: data_20250305.parquet
# Procesando: 20250306
# Guardado: data_20250306.parquet
# Procesando: 20250307
# Guardado: data_20250307.parquet
# Procesando: 20250308
# Guardado: data_20250308.parquet
# Procesando: 20250309
# Guardado: data_20250309.parquet
# Procesando: 20250310
# Guardado: data_20250310.parquet
# Procesando: 20250311
# Guardado: data_20250311.parquet
# Procesando: 20250312
# Guardado: data_20250312.parquet
# Procesando: 20250313
# Guardado: data_20250313.parquet
# Procesando: 20250314
# Guardado: data_20250314.parquet
# Procesando: 20250315
# Guardado: data_20250315.parquet
# Procesando: 20250316
# Guardado: data_20250316.parquet
# Procesando: 20250317
# Guardado: data_20250317.parquet
# Procesando: 20250318
# Guardado: data_20250318.parquet
# Procesando: 20250319
# Guardado: data_20250319.parquet
# Procesando: 20250320
# Guardado: data_20250320.parquet
# Procesando: 20250321
# Guardado: data_20250321.parquet
# Procesando: 20250322
# Guardado: data_20250322.parquet
# Procesando: 20250323
# Guardado: data_20250323.parquet
# Procesando: 20250324
# Guardado: data_20250324.parquet
# Procesando: 20250325
# Guardado: data_20250325.parquet
# Procesando: 20250326
# Faltan: ActivePower
# Guardado: data_20250326.parquet
# Procesando: 20250327
# Faltan: ActivePower
# Guardado: data_20250327.parquet
# Procesando: 20250328
# Faltan: ActivePower
# Guardado: data_20250328.parquet
# Procesando: 20250329
# Faltan: ActivePower
# Guardado: data_20250329.parquet
# Procesando: 20250330
# Faltan: ActivePower
# Guardado: data_20250330.parquet
# Procesando: 20250331
# Faltan: ActivePower
# Guardado: data_20250331.parquet
#
# Mes: 04_Abril
# Procesando: 20250401
# Faltan: ActivePower
# Guardado: data_20250401.parquet
# Procesando: 20250402
# Faltan: ActivePower
# Guardado: data_20250402.parquet
# Procesando: 20250403
# Faltan: ActivePower
# Guardado: data_20250403.parquet
# Procesando: 20250404
# Faltan: ActivePower
# Guardado: data_20250404.parquet
# Procesando: 20250405
# Faltan: ActivePower
# Guardado: data_20250405.parquet
# Procesando: 20250406
# Faltan: ActivePower
# Guardado: data_20250406.parquet
# Procesando: 20250407
# Faltan: ActivePower
# Guardado: data_20250407.parquet
# Procesando: 20250408
# Faltan: ActivePower
# Guardado: data_20250408.parquet
# Procesando: 20250409
# Faltan: ActivePower
# Guardado: data_20250409.parquet
# Procesando: 20250410
# Faltan: ActivePower
# Guardado: data_20250410.parquet
# Procesando: 20250411
# Faltan: ActivePower
# Guardado: data_20250411.parquet
# Procesando: 20250412
# Faltan: ActivePower
# Guardado: data_20250412.parquet
# Procesando: 20250413
# Faltan: ActivePower
# Guardado: data_20250413.parquet
# Procesando: 20250414
# Faltan: ActivePower
# Guardado: data_20250414.parquet
# Procesando: 20250415
# Faltan: ActivePower
# Guardado: data_20250415.parquet
# Procesando: 20250416
# Faltan: ActivePower
# Guardado: data_20250416.parquet
# Procesando: 20250417
# Faltan: ActivePower
# Guardado: data_20250417.parquet
# Procesando: 20250418
# Faltan: ActivePower
# Guardado: data_20250418.parquet
# Procesando: 20250419
# Faltan: ActivePower
# Guardado: data_20250419.parquet
# Procesando: 20250420
# Faltan: ActivePower
# Guardado: data_20250420.parquet
# Procesando: 20250421
# Faltan: ActivePower
# Guardado: data_20250421.parquet
# Procesando: 20250422
# Faltan: ActivePower
# Guardado: data_20250422.parquet
# Procesando: 20250423
# Faltan: ActivePower
# Guardado: data_20250423.parquet
# Procesando: 20250424
# Faltan: ActivePower
# Guardado: data_20250424.parquet
# Procesando: 20250425
# Faltan: ActivePower
# Guardado: data_20250425.parquet
# Procesando: 20250426
# Faltan: ActivePower
# Guardado: data_20250426.parquet
# Procesando: 20250427
# Faltan: ActivePower
# Guardado: data_20250427.parquet
# Procesando: 20250428
# Faltan: ActivePower
# Guardado: data_20250428.parquet
# Procesando: 20250429
# Faltan: ActivePower
# Guardado: data_20250429.parquet
# Procesando: 20250430
# Faltan: ActivePower
# Guardado: data_20250430.parquet
#
# Mes: 05_Mayo
# Procesando: 20250501
# Faltan: ActivePower
# Guardado: data_20250501.parquet
# Procesando: 20250502
# Faltan: ActivePower
# Guardado: data_20250502.parquet
# Procesando: 20250503
# Faltan: ActivePower
# Guardado: data_20250503.parquet
# Procesando: 20250504
# Faltan: ActivePower
# Guardado: data_20250504.parquet
# Procesando: 20250505
# Faltan: ActivePower
# Guardado: data_20250505.parquet
# Procesando: 20250506
# Faltan: ActivePower
# Guardado: data_20250506.parquet
# Procesando: 20250507
# Faltan: ActivePower
# Guardado: data_20250507.parquet
# Procesando: 20250508
# Faltan: ActivePower
# Guardado: data_20250508.parquet
# Procesando: 20250509
# Faltan: ActivePower
# Guardado: data_20250509.parquet
# Procesando: 20250510
# Faltan: ActivePower
# Guardado: data_20250510.parquet
# Procesando: 20250511
# Faltan: ActivePower
# Guardado: data_20250511.parquet
# Procesando: 20250512
# Faltan: ActivePower
# Guardado: data_20250512.parquet
# Procesando: 20250513
# Faltan: ActivePower
# Guardado: data_20250513.parquet
# Procesando: 20250514
# Faltan: ActivePower
# Guardado: data_20250514.parquet
# Procesando: 20250515
# Faltan: ActivePower
# Guardado: data_20250515.parquet
# Procesando: 20250516
# Faltan: ActivePower
# Guardado: data_20250516.parquet
# Procesando: 20250517
# Faltan: ActivePower
# Guardado: data_20250517.parquet
# Procesando: 20250518
# Faltan: ActivePower
# Guardado: data_20250518.parquet
# Procesando: 20250519
# Faltan: ActivePower
# Guardado: data_20250519.parquet
# Procesando: 20250520
# Faltan: ActivePower
# Guardado: data_20250520.parquet
# Procesando: 20250521
# Faltan: ActivePower
# Guardado: data_20250521.parquet
# Procesando: 20250522
# Faltan: ActivePower
# Guardado: data_20250522.parquet
# Procesando: 20250523
# Faltan: ActivePower
# Guardado: data_20250523.parquet
# Procesando: 20250524
# Faltan: ActivePower
# Guardado: data_20250524.parquet
# Procesando: 20250525
# Faltan: ActivePower
# Guardado: data_20250525.parquet
# Procesando: 20250526
# Faltan: ActivePower
# Guardado: data_20250526.parquet
# Procesando: 20250527
# Faltan: ActivePower
# Guardado: data_20250527.parquet
# Procesando: 20250528
# Faltan: ActivePower
# Guardado: data_20250528.parquet
# Procesando: 20250529
# Faltan: ActivePower
# Guardado: data_20250529.parquet
# Procesando: 20250530
# Faltan: ActivePower
# Guardado: data_20250530.parquet
# Procesando: 20250531
# Faltan: ActivePower
# Guardado: data_20250531.parquet
#
# Mes: 06_Junio
# Procesando: 20250601
# Faltan: ActivePower
# Guardado: data_20250601.parquet
# Procesando: 20250602
# Faltan: ActivePower
# Guardado: data_20250602.parquet
# Procesando: 20250603
# Faltan: ActivePower
# Guardado: data_20250603.parquet
# Procesando: 20250604
# Faltan: ActivePower
# Guardado: data_20250604.parquet
# Procesando: 20250605
# Faltan: ActivePower
# Guardado: data_20250605.parquet
# Procesando: 20250606
# Faltan: ActivePower
# Guardado: data_20250606.parquet
# Procesando: 20250607
# Faltan: ActivePower
# Guardado: data_20250607.parquet
# Procesando: 20250608
# Faltan: ActivePower
# Guardado: data_20250608.parquet
# Procesando: 20250609
# Faltan: ActivePower
# Guardado: data_20250609.parquet
# Procesando: 20250610
# Faltan: ActivePower
# Guardado: data_20250610.parquet
# Procesando: 20250611
# Faltan: ActivePower
# Guardado: data_20250611.parquet
# Procesando: 20250612
# Faltan: ActivePower
# Guardado: data_20250612.parquet
# Procesando: 20250613
# Faltan: ActivePower
# Guardado: data_20250613.parquet
# Procesando: 20250614
# Faltan: ActivePower
# Guardado: data_20250614.parquet
# Procesando: 20250615
# Faltan: ActivePower
# Guardado: data_20250615.parquet
# Procesando: 20250616
# Faltan: ActivePower
# Guardado: data_20250616.parquet
# Procesando: 20250617
# Faltan: ActivePower
# Guardado: data_20250617.parquet
# Procesando: 20250618
# Faltan: ActivePower
# Guardado: data_20250618.parquet
# Procesando: 20250619
# Faltan: ActivePower
# Guardado: data_20250619.parquet
# Procesando: 20250620
# Faltan: ActivePower
# Guardado: data_20250620.parquet
# Procesando: 20250621
# Faltan: ActivePower
# Guardado: data_20250621.parquet
# Procesando: 20250622
# Faltan: ActivePower
# Guardado: data_20250622.parquet
# Procesando: 20250623
# Faltan: ActivePower
# Guardado: data_20250623.parquet
# Procesando: 20250624
# Faltan: ActivePower
# Guardado: data_20250624.parquet
# Procesando: 20250625
# Faltan: ActivePower
# Guardado: data_20250625.parquet
# Procesando: 20250626
# Faltan: ActivePower
# Guardado: data_20250626.parquet
# Procesando: 20250627
# Faltan: ActivePower
# Guardado: data_20250627.parquet
# Procesando: 20250628
# Faltan: ActivePower
# Guardado: data_20250628.parquet
# Procesando: 20250629
# Faltan: ActivePower
# Guardado: data_20250629.parquet
# Procesando: 20250630
# Faltan: ActivePower
# Guardado: data_20250630.parquet
#
# Mes: 07_Julio
# Procesando: 20250701
# Faltan: ActivePower
# Guardado: data_20250701.parquet
# Procesando: 20250702
# Faltan: ActivePower
# Guardado: data_20250702.parquet
# Procesando: 20250703
# Faltan: ActivePower
# Guardado: data_20250703.parquet
# Procesando: 20250704
# Faltan: ActivePower
# Guardado: data_20250704.parquet
# Procesando: 20250705
# Faltan: ActivePower
# Guardado: data_20250705.parquet
# Procesando: 20250706
# Faltan: ActivePower
# Guardado: data_20250706.parquet
# Procesando: 20250707
# Faltan: ActivePower
# Guardado: data_20250707.parquet
# Procesando: 20250708
# Faltan: ActivePower
# Guardado: data_20250708.parquet
# Procesando: 20250709
# Faltan: ActivePower
# Guardado: data_20250709.parquet
# Procesando: 2025071
# Faltan: ActivePower
# Guardado: data_2025071.parquet
# Procesando: 20250710
# Faltan: ActivePower
# Guardado: data_20250710.parquet
# Procesando: 20250711
# Faltan: ActivePower
# Guardado: data_20250711.parquet
# Procesando: 20250712
# Faltan: ActivePower
# Guardado: data_20250712.parquet
# Procesando: 20250713
# Faltan: ActivePower
# Guardado: data_20250713.parquet
# Procesando: 20250714
# Faltan: ActivePower
# Guardado: data_20250714.parquet
# Procesando: 20250715
# Faltan: ActivePower
# Guardado: data_20250715.parquet
# Procesando: 20250716
# Faltan: ActivePower
# Guardado: data_20250716.parquet
# Procesando: 20250717
# Faltan: ActivePower
# Guardado: data_20250717.parquet
# Procesando: 20250718
# Faltan: ActivePower
# Guardado: data_20250718.parquet
# Procesando: 20250719
# Faltan: ActivePower
# Guardado: data_20250719.parquet
# Procesando: 20250720
# Faltan: ActivePower
# Guardado: data_20250720.parquet
# Procesando: 20250721
# Faltan: ActivePower
# Guardado: data_20250721.parquet
# Procesando: 20250722
# Faltan: ActivePower
# Guardado: data_20250722.parquet
# Procesando: 20250723
# Faltan: ActivePower
# Guardado: data_20250723.parquet
# Procesando: 20250724
# Faltan: ActivePower
# Guardado: data_20250724.parquet
# Procesando: 20250725
# Faltan: ActivePower
# Guardado: data_20250725.parquet
# Procesando: 20250726
# Faltan: ActivePower
# Guardado: data_20250726.parquet
# Procesando: 20250727
# Faltan: ActivePower
# Guardado: data_20250727.parquet
# Procesando: 20250728
# Faltan: ActivePower
# Guardado: data_20250728.parquet
# Procesando: 20250729
# Faltan: ActivePower
# Guardado: data_20250729.parquet
# Procesando: 20250730
# Faltan: ActivePower
# Guardado: data_20250730.parquet
# Procesando: 20250731
# Faltan: ActivePower
# Guardado: data_20250731.parquet
#
# Mes: 08_Agosto
# Procesando: 20250801
# Faltan: ActivePower
# Guardado: data_20250801.parquet
# Procesando: 20250802
# Faltan: ActivePower
# Guardado: data_20250802.parquet
# Procesando: 20250803
# Faltan: ActivePower
# Guardado: data_20250803.parquet
# Procesando: 20250804
# Faltan: ActivePower
# Guardado: data_20250804.parquet
# Procesando: 20250805
# Faltan: ActivePower
# Guardado: data_20250805.parquet
# Procesando: 20250806
# Faltan: ActivePower
# Guardado: data_20250806.parquet
# Procesando: 20250807
# Faltan: ActivePower
# Guardado: data_20250807.parquet
# Procesando: 20250808
# Faltan: ActivePower
# Guardado: data_20250808.parquet
# Procesando: 20250809
# Faltan: ActivePower
# Guardado: data_20250809.parquet
# Procesando: 20250810
# Faltan: ActivePower
# Guardado: data_20250810.parquet
# Procesando: 20250811
# Faltan: ActivePower
# Guardado: data_20250811.parquet
# Procesando: 20250812
# Faltan: ActivePower
# Guardado: data_20250812.parquet
# Procesando: 20250813
# Faltan: ActivePower
# Guardado: data_20250813.parquet
# Procesando: 20250814
# Faltan: ActivePower
# Guardado: data_20250814.parquet
# Procesando: 20250815
# Faltan: ActivePower
# Guardado: data_20250815.parquet
# Procesando: 20250816
# Faltan: ActivePower
# Guardado: data_20250816.parquet
# Procesando: 20250817
# Faltan: ActivePower
# Guardado: data_20250817.parquet
# Procesando: 20250818
# Faltan: ActivePower
# Guardado: data_20250818.parquet
# Procesando: 20250819
# Faltan: ActivePower
# Guardado: data_20250819.parquet
# Procesando: 2025082
# Faltan: ActivePower
# Guardado: data_2025082.parquet
# Procesando: 20250820
# Faltan: ActivePower
# Guardado: data_20250820.parquet
# Procesando: 20250821
# Faltan: ActivePower
# Guardado: data_20250821.parquet
# Procesando: 20250822
# Faltan: ActivePower
# Guardado: data_20250822.parquet
# Procesando: 20250823
# Faltan: ActivePower
# Guardado: data_20250823.parquet
# Procesando: 20250824
# Faltan: ActivePower
# Guardado: data_20250824.parquet
# Procesando: 20250825
# Faltan: ActivePower
# Guardado: data_20250825.parquet
# Procesando: 20250826
# Faltan: ActivePower
# Guardado: data_20250826.parquet
# Procesando: 20250827
# Faltan: ActivePower
# Guardado: data_20250827.parquet
# Procesando: 20250828
# Faltan: ActivePower
# Guardado: data_20250828.parquet
# Procesando: 20250829
# Faltan: ActivePower
# Guardado: data_20250829.parquet
# Procesando: 20250830
# Faltan: ActivePower
# Guardado: data_20250830.parquet
# Procesando: 20250831
# Faltan: ActivePower
# Guardado: data_20250831.parquet
#
# Mes: 09_Septiembre
# Procesando: 20250901
# Faltan: ActivePower
# Guardado: data_20250901.parquet
# Procesando: 20250902
# Faltan: ActivePower
# Guardado: data_20250902.parquet
# Procesando: 20250903
# Faltan: ActivePower
# Guardado: data_20250903.parquet
# Procesando: 20250904
# Faltan: ActivePower
# Guardado: data_20250904.parquet
# Procesando: 20250905
# Faltan: ActivePower
# Guardado: data_20250905.parquet
# Procesando: 20250906
# Faltan: ActivePower
# Guardado: data_20250906.parquet
# Procesando: 20250907
# Faltan: ActivePower
# Guardado: data_20250907.parquet
# Procesando: 20250908
# Faltan: ActivePower
# Guardado: data_20250908.parquet
# Procesando: 20250909
# Faltan: ActivePower
# Guardado: data_20250909.parquet
# Procesando: 20250910
# Faltan: ActivePower
# Guardado: data_20250910.parquet
# Procesando: 20250911
# Faltan: ActivePower
# Guardado: data_20250911.parquet
# Procesando: 20250912
# Faltan: ActivePower
# Guardado: data_20250912.parquet
# Procesando: 20250913
# Faltan: ActivePower
# Guardado: data_20250913.parquet
# Procesando: 20250914
# Faltan: ActivePower
# Guardado: data_20250914.parquet
# Procesando: 20250915
# Faltan: ActivePower
# Guardado: data_20250915.parquet
# Procesando: 20250916
# Faltan: ActivePower
# Guardado: data_20250916.parquet
# Procesando: 20250917
# Faltan: ActivePower
# Guardado: data_20250917.parquet
# Procesando: 20250918
# Faltan: ActivePower
# Guardado: data_20250918.parquet
# Procesando: 20250919
# Faltan: ActivePower
# Guardado: data_20250919.parquet
# Procesando: 20250920
# Faltan: ActivePower
# Guardado: data_20250920.parquet
# Procesando: 20250921
# Faltan: ActivePower
# Guardado: data_20250921.parquet
# Procesando: 20250922
# Faltan: ActivePower
# Guardado: data_20250922.parquet
# Procesando: 20250923
# Faltan: ActivePower
# Guardado: data_20250923.parquet
# Procesando: 20250924
# Faltan: ActivePower
# Guardado: data_20250924.parquet
# Procesando: 20250925
# Faltan: ActivePower
# Guardado: data_20250925.parquet
# Procesando: 20250926
# Faltan: ActivePower
# Guardado: data_20250926.parquet
# Procesando: 20250927
# Faltan: ActivePower
# Guardado: data_20250927.parquet
# Procesando: 20250928
# Faltan: ActivePower
# Guardado: data_20250928.parquet
# Procesando: 20250929
# Faltan: ActivePower
# Guardado: data_20250929.parquet
# Procesando: 20250930
# Faltan: ActivePower
# Guardado: data_20250930.parquet
#
# Mes: 10_Octubre
# Procesando: 20251001
# Faltan: ActivePower
# Guardado: data_20251001.parquet
# Procesando: 20251002
# Faltan: ActivePower
# Guardado: data_20251002.parquet
# Procesando: 20251003
# Faltan: ActivePower
# Guardado: data_20251003.parquet
# Procesando: 20251004
# Faltan: ActivePower
# Guardado: data_20251004.parquet
# Procesando: 20251005
# Faltan: ActivePower
# Guardado: data_20251005.parquet
# Procesando: 20251006
# Faltan: ActivePower
# Guardado: data_20251006.parquet
# Procesando: 20251007
# Faltan: ActivePower
# Guardado: data_20251007.parquet
# Procesando: 20251008
# Faltan: ActivePower
# Guardado: data_20251008.parquet
# Procesando: 20251009
# Faltan: ActivePower
# Guardado: data_20251009.parquet
# Procesando: 20251010
# Faltan: ActivePower
# Guardado: data_20251010.parquet
# Procesando: 20251011
# Faltan: ActivePower
# Guardado: data_20251011.parquet
# Procesando: 20251012
# Faltan: ActivePower
# Guardado: data_20251012.parquet
# Procesando: 20251013
# Faltan: ActivePower
# Guardado: data_20251013.parquet
# Procesando: 20251014
# Faltan: ActivePower
# Guardado: data_20251014.parquet
# Procesando: 20251015
# Faltan: ActivePower
# Guardado: data_20251015.parquet
# Procesando: 20251016
# Faltan: ActivePower
# Guardado: data_20251016.parquet
# Procesando: 20251017
# Faltan: ActivePower
# Guardado: data_20251017.parquet
# Procesando: 20251018
# Faltan: ActivePower
# Guardado: data_20251018.parquet
# Procesando: 20251019
# Faltan: ActivePower
# Guardado: data_20251019.parquet
# Procesando: 20251020
# Faltan: ActivePower
# Guardado: data_20251020.parquet
# Procesando: 20251021
# Faltan: ActivePower
# Guardado: data_20251021.parquet
# Procesando: 20251022
# Faltan: ActivePower
# Guardado: data_20251022.parquet
# Procesando: 20251023
# Faltan: ActivePower
# Guardado: data_20251023.parquet
# Procesando: 20251024
# Faltan: ActivePower
# Guardado: data_20251024.parquet
# Procesando: 20251025
# Faltan: ActivePower
# Guardado: data_20251025.parquet
# Procesando: 20251026
# Faltan: ActivePower
# Guardado: data_20251026.parquet
# Procesando: 20251027
# Faltan: ActivePower
# Guardado: data_20251027.parquet
# Procesando: 20251028
# Faltan: ActivePower
# Guardado: data_20251028.parquet
# Procesando: 20251029
# Faltan: ActivePower
# Guardado: data_20251029.parquet
# Procesando: 20251030
# Faltan: ActivePower
# Guardado: data_20251030.parquet
# Procesando: 20251031
# Faltan: ActivePower
# Guardado: data_20251031.parquet
#
# Mes: 11_Noviembre
# Procesando: 20251101
# Faltan: ActivePower
# Guardado: data_20251101.parquet
# Procesando: 20251102
# Faltan: ActivePower
# Guardado: data_20251102.parquet
# Procesando: 20251103
# Faltan: ActivePower
# Guardado: data_20251103.parquet
# Procesando: 20251104
# Faltan: ActivePower
# Guardado: data_20251104.parquet
# Procesando: 20251105
# Faltan: ActivePower
# Guardado: data_20251105.parquet
# Procesando: 20251106
# Faltan: ActivePower
# Guardado: data_20251106.parquet
# Procesando: 20251107
# Faltan: ActivePower
# Guardado: data_20251107.parquet
# Procesando: 20251108
# Faltan: ActivePower
# Guardado: data_20251108.parquet
# Procesando: 20251109
# Faltan: ActivePower
# Guardado: data_20251109.parquet
# Procesando: 20251110
# Faltan: ActivePower
# Guardado: data_20251110.parquet
# Procesando: 20251111
# Faltan: ActivePower
# Guardado: data_20251111.parquet
# Procesando: 20251112
# Faltan: ActivePower
# Guardado: data_20251112.parquet
# Procesando: 20251113
# Faltan: ActivePower
# Guardado: data_20251113.parquet
# Procesando: 20251114
# Faltan: ActivePower
# Guardado: data_20251114.parquet
# Procesando: 20251115
# Faltan: ActivePower
# Guardado: data_20251115.parquet
# Procesando: 20251116
# Faltan: ActivePower
# Guardado: data_20251116.parquet
# Procesando: 20251117
# Faltan: ActivePower
# Guardado: data_20251117.parquet
# Procesando: 20251118
# Faltan: ActivePower
# Guardado: data_20251118.parquet
# Procesando: 20251119
# Faltan: ActivePower
# Guardado: data_20251119.parquet
# Procesando: 20251120
# Faltan: ActivePower
# Guardado: data_20251120.parquet
# Procesando: 20251121
# Faltan: ActivePower
# Guardado: data_20251121.parquet
# Procesando: 20251122
# Faltan: ActivePower
# Guardado: data_20251122.parquet
# Procesando: 20251123
# Faltan: ActivePower
# Guardado: data_20251123.parquet
# Procesando: 20251124
# Faltan: ActivePower
# Guardado: data_20251124.parquet
# Procesando: 20251125
# Faltan: ActivePower
# Guardado: data_20251125.parquet
# Procesando: 20251126
# Faltan: ActivePower
# Guardado: data_20251126.parquet
# Procesando: 20251127
# Faltan: ActivePower
# Guardado: data_20251127.parquet
# Procesando: 20251128
# Faltan: ActivePower
# Guardado: data_20251128.parquet
# Procesando: 20251129
# Faltan: ActivePower
# Guardado: data_20251129.parquet
# Procesando: 20251130
# Faltan: ActivePower
# Guardado: data_20251130.parquet
#
# Mes: 12_Diciembre
# Procesando: 20251201
# Faltan: ActivePower
# Guardado: data_20251201.parquet
# Total de dias procesados: 705

# %%
# verificar
parquet_files = sorted(glob.glob("procesados/*.parquet"))
print(f"Total de archivos procesados: {len(parquet_files)}")

if parquet_files:
    sample_file = parquet_files[0]
    df_sample = pd.read_parquet(sample_file)
    
    print(f"\nMuestra de: {sample_file}")
    print(f"   - Shape: {df_sample.shape}")
    print(f"   - Columnas: {df_sample.columns.tolist()}")
    print(f"\n   Primeras filas:")
    print(df_sample.head(3))
# Out:
# Total de archivos procesados: 705
#
# Muestra de: procesados/data_20240101.parquet
#    - Shape: (144, 34)
#    - Columnas: ['Time', 'GEN_Generator speed-Max', 'GEN_Generator speed-Aver', 'GEN_Generator speed-Min', 'WIND_Wind direction 1s-Max', 'WIND_Wind direction 1s-Aver', 'WIND_Wind direction 1s-Min', 'WIND_Wind direction 10s-Max', 'WIND_Wind direction 10s-Aver', 'WIND_Wind direction 10s-Min', 'WIND_Wind direction 30s-Max', 'WIND_Wind direction 30s-Aver', 'WIND_Wind direction 30s-Min', 'WIND_Wind speed 1s-Max', 'WIND_Wind speed 1s-Aver', 'WIND_Wind speed 1s-Min', 'WIND_Wind speed 30s-Max', 'WIND_Wind speed 30s-Aver', 'WIND_Wind speed 30s-Min', 'WIND_Wind speed 10min-Max', 'WIND_Wind speed 10min-Aver', 'WIND_Wind speed 10min-Min', 'PWR_TotalActivePower-Max', 'PWR_TotalActivePower-Aver', 'PWR_TotalActivePower-Min', 'PWR_TotalRevActivePower-Max', 'PWR_TotalRevActivePower-Aver', 'PWR_TotalRevActivePower-Min', 'PWR_TotalReactivePower-Max', 'PWR_TotalReactivePower-Aver', 'PWR_TotalReactivePower-Min', 'AIR_Air density-Max', 'AIR_Air density-Aver', 'AIR_Air density-Min']
#
#    Primeras filas:
#                  Time  GEN_Generator speed-Max  GEN_Generator speed-Aver  \
# 0 2024-01-01 00:00:00                      0.0                       0.0
# 1 2024-01-01 00:10:00                      0.0                       0.0
# 2 2024-01-01 00:20:00                      0.0                       0.0
#
#    GEN_Generator speed-Min  WIND_Wind direction 1s-Max  \
# 0                   -0.005                   36.209286
# 1                    0.000                  -10.822143
# 2                    0.000                  154.156429
#
#    WIND_Wind direction 1s-Aver  WIND_Wind direction 1s-Min  \
# 0                   -55.699286                 -147.395000
# 1                   -80.090000                 -158.140714
# 2                   -26.187143                 -177.332143
#
#    WIND_Wind direction 10s-Max  WIND_Wind direction 10s-Aver  \
# 0                    34.434286                    -55.877857
# 1                   -13.260714                    -80.537857
# 2                   139.455000                    -26.220000
#
#    WIND_Wind direction 10s-Min  ...  PWR_TotalActivePower-Min  \
# 0                  -145.594286  ...              9.896061e+06
# 1                  -154.407143  ...              9.896061e+06
# 2                  -169.490714  ...              9.896061e+06
#
#    PWR_TotalRevActivePower-Max  PWR_TotalRevActivePower-Aver  \
# 0                103921.928571                 103919.850714
# 1                103926.000000                 103924.048571
# 2                103930.428571                 103928.260714
#
#    PWR_TotalRevActivePower-Min  PWR_TotalReactivePower-Max  \
# 0                103917.785714                13851.428571
# 1                103921.928571                13851.428571
# 2                103926.000000                13851.428571
#
#    PWR_TotalReactivePower-Aver  PWR_TotalReactivePower-Min  \
# 0                 13851.428571                13851.428571
# 1                 13851.428571                13851.428571
# 2                 13851.428571                13851.428571
#
#    AIR_Air density-Max  AIR_Air density-Aver  AIR_Air density-Min
# 0                1.035                 1.035                1.035
# 1                1.035                 1.035                1.035
# 2                1.035                 1.035                1.035
#
# [3 rows x 34 columns]
